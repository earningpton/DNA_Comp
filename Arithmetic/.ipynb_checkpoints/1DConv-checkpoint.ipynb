# %%
from __future__ import print_function

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.datasets import imdb

# Embedding
max_features = 20000
maxlen = 100
embedding_size = 128

# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# LSTM
lstm_output_size = 70

# Training
batch_size = 30
epochs = 2

'''
Note:
batch_size is highly sensitive.
Only 2 epochs are needed as the dataset is very small.
'''

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Build model...')

model = Sequential()
model.add(Embedding(max_features, embedding_size, input_length=maxlen))
model.add(Dropout(0.25))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
model.add(MaxPooling1D(pool_size=pool_size))
model.add(LSTM(lstm_output_size))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Loading data...
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 100)
# x_test shape: (25000, 100)
# Build model...
# Train...
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/2
# 25000/25000 [==============================] - 47s 2ms/sample - loss: 0.3868 - accuracy: 0.8168 - val_loss: 0.3141 - val_accuracy: 0.8635
# Epoch 2/2
# 25000/25000 [==============================] - 36s 1ms/sample - loss: 0.1942 - accuracy: 0.9258 - val_loss: 0.3491 - val_accuracy: 0.8556
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 0.3490920394256711
# Test accuracy: 0.85564

# %%
x_train.shape
# Out:
# (25000, 100)

# %%
import arithc as arith
import fqt, ppm
import contextlib, sys
import filecmp
from IPython.display import clear_output
import numpy as np

from tensorflow.keras.utils import to_categorical

# %%
list_of_lists = []
with open('data\ecoli\Ecoli.txt') as f:
    for line in f:
        #inner_list = [elt.strip() for elt in line.split()]
        inner_list = list(line)
        list_of_lists.append(inner_list)
print(len(list_of_lists[0])) # About 4 MB
ecoli = list_of_lists[0]


s = ecoli
char_list = [97, 103, 99, 116] # we can read this as we go
print(char_list)
update_period = len(s)

k = 64 #context length
n = 100000 # train every
legend = dict([(v, k) for k, v in enumerate(char_list)]) # map character to 0,1,2,3,4, etc.
vocab_size = len(char_list)

temp_dict = {'a':97,'g': 103,'c': 99,'t': 116}
s = [temp_dict[i] for i in s]
#Train model
x = np.zeros((update_period-k, k)) # 64 characters context
y = np.zeros((update_period-k, vocab_size))


print(len(s))
idx3 = 0
for idx2 in range(k,len(s)):
    train_seq = [legend[i] for i in s[idx2-k:idx2]] 
    train_target = legend[s[idx2]]
    x[idx3,:] = np.array(train_seq)
    y[idx3] = to_categorical(train_target, num_classes=vocab_size )
    idx3 += 1
# Out:
# 4638690
# [97, 103, 99, 116]
# 4638690

# %%
from __future__ import print_function

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.datasets import imdb

# Embedding
max_features = 20000
maxlen = k
embedding_size = 128

# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# LSTM
lstm_output_size = 70

# Training
batch_size = 30
epochs = 2

seq_length = 256  #Length of the sequence to be inserted into the LSTM
vocab_size = len(char_list)  #Size of the final dense layer of the model
lstm_cells = 32  #Size of the LSTM layer


D1LSTM = Sequential()
D1LSTM.add(Embedding(max_features, embedding_size, input_length=k))
D1LSTM.add(Dropout(0.25))
D1LSTM.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
D1LSTM.add(MaxPooling1D(pool_size=pool_size))
D1LSTM.add(LSTM(lstm_cells))
D1LSTM.add(Dense(vocab_size))
D1LSTM.add(Activation('softmax'))
D1LSTM.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# %%
D1LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 64, 128)           2560000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 64)            41024
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 15, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 2,613,572
# Trainable params: 2,613,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
predicted_onehot = []
for i in range(len(ecoli)//n - 1):
    if i%5 == 0:
        print(i)
    D1LSTM.fit(x[n*i:n*(i+1)], y[n*i:n*(i+1)],
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x[n*(i+1):n*(i+2)], y[n*(i+1):n*(i+2)]))

    predicted_onehot += list(D1LSTM.predict_proba(x[n*(i+1):n*(i+2)]))
predicted_onehot += list(D1LSTM.predict_proba(x[n*(len(ecoli)//n):]))
# Out:
# 0
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 162s 2ms/sample - loss: 1.3764 - categorical_accuracy: 0.2937 - val_loss: 1.3676 - val_categorical_accuracy: 0.3094
# Epoch 2/2
# 100000/100000 [==============================] - 136s 1ms/sample - loss: 1.3615 - categorical_accuracy: 0.3187 - val_loss: 1.3608 - val_categorical_accuracy: 0.3162
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 145s 1ms/sample - loss: 1.3538 - categorical_accuracy: 0.3241 - val_loss: 1.3626 - val_categorical_accuracy: 0.3166
# Epoch 2/2
# 100000/100000 [==============================] - 140s 1ms/sample - loss: 1.3467 - categorical_accuracy: 0.3329 - val_loss: 1.3600 - val_categorical_accuracy: 0.3159
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 153s 2ms/sample - loss: 1.3544 - categorical_accuracy: 0.3240 - val_loss: 1.3549 - val_categorical_accuracy: 0.3273
# Epoch 2/2
# 100000/100000 [==============================] - 144s 1ms/sample - loss: 1.3499 - categorical_accuracy: 0.3291 - val_loss: 1.3546 - val_categorical_accuracy: 0.3252
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 150s 2ms/sample - loss: 1.3491 - categorical_accuracy: 0.3324 - val_loss: 1.3456 - val_categorical_accuracy: 0.3354
# Epoch 2/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3445 - categorical_accuracy: 0.3380 - val_loss: 1.3460 - val_categorical_accuracy: 0.3341
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 155s 2ms/sample - loss: 1.3405 - categorical_accuracy: 0.3404 - val_loss: 1.3482 - val_categorical_accuracy: 0.3373
# Epoch 2/2
# 100000/100000 [==============================] - 170s 2ms/sample - loss: 1.3358 - categorical_accuracy: 0.3483 - val_loss: 1.3440 - val_categorical_accuracy: 0.3378
# 5
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3434 - categorical_accuracy: 0.3388 - val_loss: 1.3465 - val_categorical_accuracy: 0.3384
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3393 - categorical_accuracy: 0.3442 - val_loss: 1.3440 - val_categorical_accuracy: 0.3406
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 144s 1ms/sample - loss: 1.3451 - categorical_accuracy: 0.3379 - val_loss: 1.3402 - val_categorical_accuracy: 0.3417
# Epoch 2/2
# 100000/100000 [==============================] - 162s 2ms/sample - loss: 1.3402 - categorical_accuracy: 0.3439 - val_loss: 1.3414 - val_categorical_accuracy: 0.3408
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 163s 2ms/sample - loss: 1.3411 - categorical_accuracy: 0.3406 - val_loss: 1.3413 - val_categorical_accuracy: 0.3421
# Epoch 2/2
# 100000/100000 [==============================] - 171s 2ms/sample - loss: 1.3375 - categorical_accuracy: 0.3442 - val_loss: 1.3383 - val_categorical_accuracy: 0.3426
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3387 - categorical_accuracy: 0.3432 - val_loss: 1.3421 - val_categorical_accuracy: 0.3399
# Epoch 2/2
# 100000/100000 [==============================] - 141s 1ms/sample - loss: 1.3351 - categorical_accuracy: 0.3488 - val_loss: 1.3414 - val_categorical_accuracy: 0.3419
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 143s 1ms/sample - loss: 1.3410 - categorical_accuracy: 0.3420 - val_loss: 1.3465 - val_categorical_accuracy: 0.3353
# Epoch 2/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3376 - categorical_accuracy: 0.3469 - val_loss: 1.3453 - val_categorical_accuracy: 0.3363
# 10
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 143s 1ms/sample - loss: 1.3462 - categorical_accuracy: 0.3344 - val_loss: 1.3423 - val_categorical_accuracy: 0.3391
# Epoch 2/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3437 - categorical_accuracy: 0.3403 - val_loss: 1.3437 - val_categorical_accuracy: 0.3379
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 154s 2ms/sample - loss: 1.3431 - categorical_accuracy: 0.3399 - val_loss: 1.3483 - val_categorical_accuracy: 0.3350
# Epoch 2/2
# 100000/100000 [==============================] - 150s 2ms/sample - loss: 1.3387 - categorical_accuracy: 0.3457 - val_loss: 1.3488 - val_categorical_accuracy: 0.3345
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 146s 1ms/sample - loss: 1.3487 - categorical_accuracy: 0.3331 - val_loss: 1.3409 - val_categorical_accuracy: 0.3417
# Epoch 2/2
# 100000/100000 [==============================] - 144s 1ms/sample - loss: 1.3473 - categorical_accuracy: 0.3349 - val_loss: 1.3419 - val_categorical_accuracy: 0.3418
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 156s 2ms/sample - loss: 1.3439 - categorical_accuracy: 0.3378 - val_loss: 1.3539 - val_categorical_accuracy: 0.3291
# Epoch 2/2
# 100000/100000 [==============================] - 150s 1ms/sample - loss: 1.3395 - categorical_accuracy: 0.3440 - val_loss: 1.3494 - val_categorical_accuracy: 0.3312
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3487 - categorical_accuracy: 0.3318 - val_loss: 1.3499 - val_categorical_accuracy: 0.3305
# Epoch 2/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3465 - categorical_accuracy: 0.3361 - val_loss: 1.3503 - val_categorical_accuracy: 0.3316
# 15
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3499 - categorical_accuracy: 0.3299 - val_loss: 1.3502 - val_categorical_accuracy: 0.3344
# Epoch 2/2
# 100000/100000 [==============================] - 154s 2ms/sample - loss: 1.3466 - categorical_accuracy: 0.3359 - val_loss: 1.3504 - val_categorical_accuracy: 0.3348
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 161s 2ms/sample - loss: 1.3507 - categorical_accuracy: 0.3329 - val_loss: 1.3468 - val_categorical_accuracy: 0.3358
# Epoch 2/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3478 - categorical_accuracy: 0.3361 - val_loss: 1.3468 - val_categorical_accuracy: 0.3344
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 153s 2ms/sample - loss: 1.3467 - categorical_accuracy: 0.3360 - val_loss: 1.3440 - val_categorical_accuracy: 0.3392
# Epoch 2/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3426 - categorical_accuracy: 0.3423 - val_loss: 1.3437 - val_categorical_accuracy: 0.3408
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 167s 2ms/sample - loss: 1.3444 - categorical_accuracy: 0.3396 - val_loss: 1.3418 - val_categorical_accuracy: 0.3422
# Epoch 2/2
# 100000/100000 [==============================] - 151s 2ms/sample - loss: 1.3428 - categorical_accuracy: 0.3418 - val_loss: 1.3440 - val_categorical_accuracy: 0.3384
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3438 - categorical_accuracy: 0.3406 - val_loss: 1.3509 - val_categorical_accuracy: 0.3283
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3411 - categorical_accuracy: 0.3411 - val_loss: 1.3524 - val_categorical_accuracy: 0.3302
# 20
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3500 - categorical_accuracy: 0.3337 - val_loss: 1.3400 - val_categorical_accuracy: 0.3437
# Epoch 2/2
# 100000/100000 [==============================] - 151s 2ms/sample - loss: 1.3455 - categorical_accuracy: 0.3368 - val_loss: 1.3428 - val_categorical_accuracy: 0.3429
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 141s 1ms/sample - loss: 1.3402 - categorical_accuracy: 0.3463 - val_loss: 1.3372 - val_categorical_accuracy: 0.3480
# Epoch 2/2
# 100000/100000 [==============================] - 145s 1ms/sample - loss: 1.3371 - categorical_accuracy: 0.3493 - val_loss: 1.3398 - val_categorical_accuracy: 0.3426
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 150s 2ms/sample - loss: 1.3417 - categorical_accuracy: 0.3420 - val_loss: 1.3382 - val_categorical_accuracy: 0.3478
# Epoch 2/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3389 - categorical_accuracy: 0.3458 - val_loss: 1.3386 - val_categorical_accuracy: 0.3460
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3389 - categorical_accuracy: 0.3463 - val_loss: 1.3478 - val_categorical_accuracy: 0.3372
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3374 - categorical_accuracy: 0.3479 - val_loss: 1.3464 - val_categorical_accuracy: 0.3377
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3496 - categorical_accuracy: 0.3336 - val_loss: 1.3378 - val_categorical_accuracy: 0.3459
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3468 - categorical_accuracy: 0.3367 - val_loss: 1.3370 - val_categorical_accuracy: 0.3461
# 25
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3393 - categorical_accuracy: 0.3446 - val_loss: 1.3348 - val_categorical_accuracy: 0.3502
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3359 - categorical_accuracy: 0.3487 - val_loss: 1.3322 - val_categorical_accuracy: 0.3537
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3339 - categorical_accuracy: 0.3501 - val_loss: 1.3611 - val_categorical_accuracy: 0.3249
# Epoch 2/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3320 - categorical_accuracy: 0.3532 - val_loss: 1.3574 - val_categorical_accuracy: 0.3272
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 146s 1ms/sample - loss: 1.3552 - categorical_accuracy: 0.3277 - val_loss: 1.3442 - val_categorical_accuracy: 0.3420
# Epoch 2/2
# 100000/100000 [==============================] - 153s 2ms/sample - loss: 1.3549 - categorical_accuracy: 0.3263 - val_loss: 1.3461 - val_categorical_accuracy: 0.3363
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3427 - categorical_accuracy: 0.3401 - val_loss: 1.3460 - val_categorical_accuracy: 0.3401
# Epoch 2/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3392 - categorical_accuracy: 0.3454 - val_loss: 1.3433 - val_categorical_accuracy: 0.3419
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 136s 1ms/sample - loss: 1.3465 - categorical_accuracy: 0.3375 - val_loss: 1.3435 - val_categorical_accuracy: 0.3385
# Epoch 2/2
# 100000/100000 [==============================] - 136s 1ms/sample - loss: 1.3434 - categorical_accuracy: 0.3416 - val_loss: 1.3427 - val_categorical_accuracy: 0.3397
# 30
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 138s 1ms/sample - loss: 1.3423 - categorical_accuracy: 0.3393 - val_loss: 1.3402 - val_categorical_accuracy: 0.3447
# Epoch 2/2
# 100000/100000 [==============================] - 139s 1ms/sample - loss: 1.3383 - categorical_accuracy: 0.3457 - val_loss: 1.3421 - val_categorical_accuracy: 0.3411
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 150s 1ms/sample - loss: 1.3423 - categorical_accuracy: 0.3411 - val_loss: 1.3384 - val_categorical_accuracy: 0.3475
# Epoch 2/2
# 100000/100000 [==============================] - 150s 1ms/sample - loss: 1.3398 - categorical_accuracy: 0.3428 - val_loss: 1.3393 - val_categorical_accuracy: 0.3428
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3397 - categorical_accuracy: 0.3425 - val_loss: 1.3411 - val_categorical_accuracy: 0.3423
# Epoch 2/2
# 100000/100000 [==============================] - 150s 1ms/sample - loss: 1.3370 - categorical_accuracy: 0.3461 - val_loss: 1.3417 - val_categorical_accuracy: 0.3424
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3420 - categorical_accuracy: 0.3410 - val_loss: 1.3497 - val_categorical_accuracy: 0.3318
# Epoch 2/2
# 100000/100000 [==============================] - 160s 2ms/sample - loss: 1.3381 - categorical_accuracy: 0.3471 - val_loss: 1.3505 - val_categorical_accuracy: 0.3316
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 158s 2ms/sample - loss: 1.3526 - categorical_accuracy: 0.3276 - val_loss: 1.3428 - val_categorical_accuracy: 0.3410
# Epoch 2/2
# 100000/100000 [==============================] - 151s 2ms/sample - loss: 1.3488 - categorical_accuracy: 0.3316 - val_loss: 1.3393 - val_categorical_accuracy: 0.3461
# 35
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3382 - categorical_accuracy: 0.3446 - val_loss: 1.3402 - val_categorical_accuracy: 0.3441
# Epoch 2/2
# 100000/100000 [==============================] - 152s 2ms/sample - loss: 1.3345 - categorical_accuracy: 0.3488 - val_loss: 1.3445 - val_categorical_accuracy: 0.3397
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3404 - categorical_accuracy: 0.3456 - val_loss: 1.3421 - val_categorical_accuracy: 0.3420
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3380 - categorical_accuracy: 0.3471 - val_loss: 1.3428 - val_categorical_accuracy: 0.3401
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3435 - categorical_accuracy: 0.3406 - val_loss: 1.3480 - val_categorical_accuracy: 0.3369
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3447 - categorical_accuracy: 0.3367 - val_loss: 1.3514 - val_categorical_accuracy: 0.3301
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3451 - categorical_accuracy: 0.3402 - val_loss: 1.3435 - val_categorical_accuracy: 0.3400
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3420 - categorical_accuracy: 0.3431 - val_loss: 1.3483 - val_categorical_accuracy: 0.3353
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3463 - categorical_accuracy: 0.3369 - val_loss: 1.3462 - val_categorical_accuracy: 0.3349
# Epoch 2/2
# 100000/100000 [==============================] - 149s 1ms/sample - loss: 1.3433 - categorical_accuracy: 0.3392 - val_loss: 1.3438 - val_categorical_accuracy: 0.3413
# 40
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 136s 1ms/sample - loss: 1.3458 - categorical_accuracy: 0.3379 - val_loss: 1.3452 - val_categorical_accuracy: 0.3355
# Epoch 2/2
# 100000/100000 [==============================] - 140s 1ms/sample - loss: 1.3428 - categorical_accuracy: 0.3419 - val_loss: 1.3445 - val_categorical_accuracy: 0.3388
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 137s 1ms/sample - loss: 1.3470 - categorical_accuracy: 0.3360 - val_loss: 1.3472 - val_categorical_accuracy: 0.3349
# Epoch 2/2
# 100000/100000 [==============================] - 140s 1ms/sample - loss: 1.3454 - categorical_accuracy: 0.3380 - val_loss: 1.3415 - val_categorical_accuracy: 0.3406
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 141s 1ms/sample - loss: 1.3442 - categorical_accuracy: 0.3374 - val_loss: 1.3458 - val_categorical_accuracy: 0.3380
# Epoch 2/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3442 - categorical_accuracy: 0.3374 - val_loss: 1.3442 - val_categorical_accuracy: 0.3383
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3437 - categorical_accuracy: 0.3439 - val_loss: 1.3467 - val_categorical_accuracy: 0.3355
# Epoch 2/2
# 100000/100000 [==============================] - 147s 1ms/sample - loss: 1.3405 - categorical_accuracy: 0.3449 - val_loss: 1.3495 - val_categorical_accuracy: 0.3287
# Train on 100000 samples, validate on 100000 samples
# Epoch 1/2
# 100000/100000 [==============================] - 153s 2ms/sample - loss: 1.3470 - categorical_accuracy: 0.3331 - val_loss: 1.3506 - val_categorical_accuracy: 0.3313
# Epoch 2/2
# 100000/100000 [==============================] - 148s 1ms/sample - loss: 1.3453 - categorical_accuracy: 0.3356 - val_loss: 1.3527 - val_categorical_accuracy: 0.3310

# %%
np.save('tempura',predicted_onehot)

# %%
char_list = [97, 103, 99, 116]
def LSTM1D_Compress(inp, bitout):
    initfreqs = fqt.FlatFrequencyTable(257)
    model = fqt.SimpleFrequencyTable(initfreqs) # For the first 200,000
    enc = arith.ArithmeticCoder(32)
    enc.start_encode(bitout) # New line!

    idx = 0
    while True:
        symbol = inp.read(1)
        if len(symbol) == 0:
                break

        idx += 1
        ## Progress Evaluation ## only internal
        if idx % (len(ecoli)//10) == 0:
            print(str(10*idx//(len(ecoli)//10)) + ' percent done')
            clear_output(wait = True)
        if idx == (n+k+1):
            initfreqs = fqt.FlatFrequencyTable(257)
            model = fqt.SimpleFrequencyTable(initfreqs) # reset the model
        if idx >= (n+k+1):
            for val, prob in enumerate(predicted_onehot[idx-(n+k+1)]):
                model.set(char_list[val], int(prob*100000)+1)
            
        t = model.get_total() ## New lines!
        l = model.get_low(symbol[0])
        h = model.get_high(symbol[0])
        enc.storeRegion(l,h,t) 
        
        if idx < (n+k+1): # back up before LSTM model
            model.increment(symbol[0])
    t = model.get_total() ## New lines!
    l = model.get_low(256)
    h = model.get_high(256)
    enc.storeRegion(l,h,t)
    enc.finish_encode(bitout)  # New line!
inputfile, outputfile = 'data\ecoli\Ecoli.txt', 'data\ecoli\Ecoli_LSTM1D.txt'

#Perform file compression
with open(inputfile, "rb") as inp, \
        contextlib.closing(arith.BitOutputStream(open(outputfile, "wb"))) as bitout:
    LSTM1D_Compress(inp, bitout)
# Out:
# 100 percent done

# %% [markdown]
# ## This is very good, however, we are not sure if it's worth the trade off timewise
#
# Let's check accuracy

# %%
cc = ['a','g','c','t']
predicted_label = [cc[np.argmax(i)] for i in predicted_onehot]

print(np.sum(np.array(predicted_label) == np.array(ecoli[n+k:])))
# Out:
# 1529883

# %%
1529883/len(predicted_label)
# Out:
# 0.33708064951815814

# %% [markdown]
# 34% right!. Let's consider if we dont have 100,000 delays, and if we use final model on the entire file!

# %%
predicted_cheat = list(D1LSTM.predict_proba(x[:n]))

# %%
char_list = [97, 103, 99, 116]
def LSTM1D_Cheat_Compress(inp, bitout):
    initfreqs = fqt.FlatFrequencyTable(257)
    model = fqt.SimpleFrequencyTable(initfreqs) # For the first 200,000
    enc = arith.ArithmeticCoder(32)
    enc.start_encode(bitout) # New line!

    idx = 0
    while True:
        symbol = inp.read(1)
        if len(symbol) == 0:
                break

        idx += 1
        ## Progress Evaluation ## only internal
        if idx % (len(ecoli)//10) == 0:
            print(str(10*idx//(len(ecoli)//10)) + ' percent done')
            clear_output(wait = True)
        if idx == (k+1):
            initfreqs = fqt.FlatFrequencyTable(257)
            model = fqt.SimpleFrequencyTable(initfreqs) # reset the model
        if idx >= (n+k+1):
            for val, prob in enumerate(predicted_onehot[idx-(n+k+1)]):
                model.set(char_list[val], int(prob*100000)+1)
        elif idx >= (k+1):
            for val, prob in enumerate(predicted_cheat[idx-(k+1)]):
                model.set(char_list[val], int(prob*100000)+1)
            
        t = model.get_total() ## New lines!
        l = model.get_low(symbol[0])
        h = model.get_high(symbol[0])
        enc.storeRegion(l,h,t) 
        
        if idx < (k+1): # back up before LSTM model
            model.increment(symbol[0])
    t = model.get_total() ## New lines!
    l = model.get_low(256)
    h = model.get_high(256)
    enc.storeRegion(l,h,t)
    enc.finish_encode(bitout)  # New line!
inputfile, outputfile = 'data\ecoli\Ecoli.txt', 'data\ecoli\Ecoli_LSTM1D_cheat.txt'

#Perform file compression
with open(inputfile, "rb") as inp, \
        contextlib.closing(arith.BitOutputStream(open(outputfile, "wb"))) as bitout:
    LSTM1D_Cheat_Compress(inp, bitout)
# Out:
# 100 percent done

# %%
predicted_full = list(D1LSTM.predict_proba(x[:]))

# %%
char_list = [97, 103, 99, 116]
def LSTM1D_Cheat_Compress(inp, bitout):
    initfreqs = fqt.FlatFrequencyTable(257)
    model = fqt.SimpleFrequencyTable(initfreqs) # For the first 200,000
    enc = arith.ArithmeticCoder(32)
    enc.start_encode(bitout) # New line!

    idx = 0
    while True:
        symbol = inp.read(1)
        if len(symbol) == 0:
                break

        idx += 1
        ## Progress Evaluation ## only internal
        if idx % (len(ecoli)//10) == 0:
            print(str(10*idx//(len(ecoli)//10)) + ' percent done')
            clear_output(wait = True)
        if idx == (k+1):
            initfreqs = fqt.FlatFrequencyTable(257)
            model = fqt.SimpleFrequencyTable(initfreqs) # reset the model
        if idx >= (k+1):
            for val, prob in enumerate(predicted_full[idx-(k+1)]):
                model.set(char_list[val], int(prob*100000)+1)
            
        t = model.get_total() ## New lines!
        l = model.get_low(symbol[0])
        h = model.get_high(symbol[0])
        enc.storeRegion(l,h,t) 
        
        if idx < (k+1): # back up before LSTM model
            model.increment(symbol[0])
    t = model.get_total() ## New lines!
    l = model.get_low(256)
    h = model.get_high(256)
    enc.storeRegion(l,h,t)
    enc.finish_encode(bitout)  # New line!
inputfile, outputfile = 'data\ecoli\Ecoli.txt', 'data\ecoli\Ecoli_LSTM1D_full.txt'

#Perform file compression
with open(inputfile, "rb") as inp, \
        contextlib.closing(arith.BitOutputStream(open(outputfile, "wb"))) as bitout:
    LSTM1D_Cheat_Compress(inp, bitout)
# Out:
# 100 percent done
